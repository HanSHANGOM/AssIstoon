# %%
import os
path='D:\\opm0118\\'
names=[name.split('.')[0] for name in os.listdir(path)]
for idx, name in enumerate(names):
    splits=name.split('_')
    
    e=splits[0]
    p=splits[1]
    print()
    pnum=p.split('p')[1].zfill(3)
    p='p'+pnum
    
    aftername=e+'_'+p+'.jpg'
    print(aftername)
    afterpath=path+'/'+aftername
    beforepath=path+'/'+name+'.jpg'
    #print(afterpath)
    os.rename(beforepath,afterpath)
# Out:
# e123_p010.jpg
#
# e123_p011.jpg
#
# e123_p012.jpg
#
# e123_p013.jpg
#
# e123_p016.jpg
#
# e123_p017.jpg
#
# e123_p018.jpg
#
# e123_p019.jpg
#
# e123_p002.jpg
#
# e123_p021.jpg
#
# e123_p023.jpg
#
# e123_p024.jpg
#
# e123_p025.jpg
#
# e123_p026.jpg
#
# e123_p027.jpg
#
# e123_p029.jpg
#
# e123_p032.jpg
#
# e123_p034.jpg
#
# e123_p035.jpg
#
# e123_p036.jpg
#
# e123_p037.jpg
#
# e124_p010.jpg
#
# e124_p011.jpg
#
# e124_p012.jpg
#
# e124_p013.jpg
#
# e124_p014.jpg
#
# e124_p015.jpg
#
# e124_p016.jpg
#
# e124_p017.jpg
#
# e124_p018.jpg
#
# e124_p019.jpg
#
# e124_p002.jpg
#
# e124_p021.jpg
#
# e124_p022.jpg
#
# e124_p023.jpg
#
# e124_p025.jpg
#
# e124_p026.jpg
#
# e124_p027.jpg
#
# e124_p029.jpg
#
# e125_p010.jpg
#
# e125_p100.jpg
#
# e125_p101.jpg
#
# e125_p102.jpg
#
# e125_p103.jpg
#
# e125_p104.jpg
#
# e125_p105.jpg
#
# e125_p106.jpg
#
# e125_p107.jpg
#
# e125_p108.jpg
#
# e125_p109.jpg
#
# e125_p011.jpg
#
# e125_p110.jpg
#
# e125_p111.jpg
#
# e125_p112.jpg
#
# e125_p113.jpg
#
# ...

# %%
path='C:\\Users\\sanghoon\\AssIstoon\\sfx_extract\\dataset\\originals\\val\\masks'
names=[name.split('.')[0] for name in os.listdir(path)]
for idx, name in enumerate(names):
    splits=name.split('_')
    inst=splits[1]
    e=splits[0].split('p')[0]
    p='p'+splits[0].split('p')[1].zfill(3)
    
    aftername=e+p+'_'+inst+'.png'
    print(aftername)
    afterpath=path+'/'+aftername
    beforepath=path+'/'+name+'.png'
    #print(afterpath)
    os.rename(beforepath,afterpath)
# Out:
# e125p126_sfx-1.png
# e125p126_sfx-2.png
# e125p126_sfx-3.png
# e125p126_sfx-4.png
# e125p126_sfx-5.png
# e125p127_sfx-1.png
# e125p127_sfx-10.png
# e125p127_sfx-11.png
# e125p127_sfx-2.png
# e125p127_sfx-3.png
# e125p127_sfx-4.png
# e125p127_sfx-5.png
# e125p127_sfx-6.png
# e125p127_sfx-7.png
# e125p127_sfx-8.png
# e125p127_sfx-9.png
# e125p140_sfx-1.png
# e125p140_sfx-2.png
# e125p140_sfx-3.png
# e125p140_sfx-4.png
# e125p141_sfx-1.png
# e125p141_sfx-2.png

# %%
import os
path='D:\\opm0118\\08\\'
savepath='D:\\sfx_extract_adam_plus\\dataset\\new\\images\\'
names=[name for name in os.listdir(path)]
#print(names)
for idx, name in enumerate(names):
    filename='e008'+'_p'+name[-7:]
    os.rename(path+name,savepath+filename)

# %%
import os
root='C:/Users/sanghoon/Desktop/workspaces/inpaint/generative_inpainting-master/data_flist/'
savepath='C:/Users/sanghoon/Desktop/workspaces/inpaint/generative_inpainting-master/training_data/'
for
